# %%
import pandas as pd

# %%
df_jan = pd.read_csv("JC-202301-citibike-tripdata.csv",encoding="utf8")
df_feb = pd.read_csv("JC-202302-citibike-tripdata.csv",encoding="utf8")
df_mar = pd.read_csv("JC-202303-citibike-tripdata.csv",encoding="utf8")
df_apr = pd.read_csv("JC-202304-citibike-tripdata.csv",encoding="utf8")
df_may = pd.read_csv("JC-202305-citibike-tripdata.csv",encoding="utf8")

# %%
# pd.concat([df1, df2], axis=0)
main_df = pd.concat([df_jan,df_feb,df_mar,df_apr,df_may],axis=0)

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 347050 entries, 0 to 96001
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             347050 non-null  object
#  1   rideable_type       347050 non-null  object
#  2   started_at          347050 non-null  object
#  3   ended_at            347050 non-null  object
#  4   start_station_name  347047 non-null  object
#  5   start_station_id    347047 non-null  object
#  6   end_station_name    346019 non-null  object
#  7   end_station_id      346019 non-null  object
#  8   start_lat           347050 non-null  float64
#  9   start_lng           347050 non-null  float64
#  10  end_lat             346688 non-null  float64
#  11  end_lng             346688 non-null  float64
#  12  member_casual       347050 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 37.1+ MB

# %%
main_df["ride_id"].nunique()
# Out:
# 347050

# %%
main_df.dropna(inplace=True)

# %%
main_df["ride_id"].nunique()
# Out:
# 346019

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 346019 entries, 0 to 96001
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             346019 non-null  object
#  1   rideable_type       346019 non-null  object
#  2   started_at          346019 non-null  object
#  3   ended_at            346019 non-null  object
#  4   start_station_name  346019 non-null  object
#  5   start_station_id    346019 non-null  object
#  6   end_station_name    346019 non-null  object
#  7   end_station_id      346019 non-null  object
#  8   start_lat           346019 non-null  float64
#  9   start_lng           346019 non-null  float64
#  10  end_lat             346019 non-null  float64
#  11  end_lng             346019 non-null  float64
#  12  member_casual       346019 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 37.0+ MB

# %%
main_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  0905B18B365C9D20   classic_bike  2023-01-28 09:18:10  2023-01-28 09:28:52
# 1  B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12  2023-01-23 20:18:27
# 2  5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04  2023-01-29 15:32:38
# 3  E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08  2023-01-24 18:42:13
# 4  323165780CA0734B   classic_bike  2023-01-21 20:44:09  2023-01-21 20:48:08
#
#                          start_station_name start_station_id  \
# 0  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 1  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 2  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 3  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 4                             Hamilton Park            JC009
#
#                              end_station_name end_station_id  start_lat  \
# 0                               Hamilton Park          JC009  40.735938
# 1  Southwest Park - Jackson St & Observer Hwy          HB401  40.735938
# 2                          Marshall St & 2 St          HB408  40.735944
# 3                               Hamilton Park          JC009  40.735986
# 4                                Manila & 1st          JC082  40.727596
#
#    start_lng    end_lat    end_lng member_casual
# 0 -74.030305  40.727596 -74.044247        member
# 1 -74.030305  40.737551 -74.041664        member
# 2 -74.030383  40.740802 -74.042521        member
# 3 -74.030364  40.727596 -74.044247        member
# 4 -74.044247  40.721651 -74.042884        member

# %%
main_df.to_csv("main_concat.csv",index=False)

# %%
df_test = pd.read_csv("main_concat.csv",encoding="utf8")
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346019 entries, 0 to 346018
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             346019 non-null  object
#  1   rideable_type       346019 non-null  object
#  2   started_at          346019 non-null  object
#  3   ended_at            346019 non-null  object
#  4   start_station_name  346019 non-null  object
#  5   start_station_id    346019 non-null  object
#  6   end_station_name    346019 non-null  object
#  7   end_station_id      346019 non-null  object
#  8   start_lat           346019 non-null  float64
#  9   start_lng           346019 non-null  float64
#  10  end_lat             346019 non-null  float64
#  11  end_lng             346019 non-null  float64
#  12  member_casual       346019 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 34.3+ MB

# %%
main_df.tail()
# Out:
#                 ride_id rideable_type           started_at  \
# 95997  9549398286BB59B5   docked_bike  2023-05-27 13:24:51
# 95998  AB0790683044D89E  classic_bike  2023-05-18 17:12:07
# 95999  68226FA538A405CA  classic_bike  2023-05-05 18:44:57
# 96000  CABAC21C0F0140A5  classic_bike  2023-05-16 11:56:11
# 96001  4AABD797EF6F7BB2  classic_bike  2023-05-30 11:04:46
#
#                   ended_at                            start_station_name  \
# 95997  2023-05-27 13:51:18  South Waterfront Walkway - Sinatra Dr & 1 St
# 95998  2023-05-18 17:25:02  South Waterfront Walkway - Sinatra Dr & 1 St
# 95999  2023-05-05 18:56:15  South Waterfront Walkway - Sinatra Dr & 1 St
# 96000  2023-05-16 12:04:04                                Columbus Drive
# 96001  2023-05-30 11:13:54  South Waterfront Walkway - Sinatra Dr & 1 St
#
#       start_station_id end_station_name end_station_id  start_lat  start_lng  \
# 95997            HB103     Newport Pkwy          JC008  40.736982 -74.027781
# 95998            HB103        Warren St          JC006  40.736982 -74.027781
# 95999            HB103        Warren St          JC006  40.736982 -74.027781
# 96000            JC014     Newport Pkwy          JC008  40.718355 -74.038914
# 96001            HB103        Warren St          JC006  40.736982 -74.027781
#
#          end_lat    end_lng member_casual
# 95997  40.728745 -74.032108        casual
# 95998  40.721124 -74.038051        member
# 95999  40.721124 -74.038051        member
# 96000  40.728745 -74.032108        member
# 96001  40.721124 -74.038051        member

# %%
from math import sin, cos, sqrt, atan2, radians

# Approximate radius of earth in km
R = 6373.0

lat1 = radians(40.735938)
lon1 = radians(-74.030305)
lat2 = radians(40.727596)
lon2 = radians(-74.044247)

dlon = lon2 - lon1
dlat = lat2 - lat1

a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
c = 2 * atan2(sqrt(a), sqrt(1 - a))

distance = R * c

print("Result: ", distance)
# Out:
# Result:  1.4972930776880664

# %%
main_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  0905B18B365C9D20   classic_bike  2023-01-28 09:18:10  2023-01-28 09:28:52
# 1  B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12  2023-01-23 20:18:27
# 2  5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04  2023-01-29 15:32:38
# 3  E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08  2023-01-24 18:42:13
# 4  323165780CA0734B   classic_bike  2023-01-21 20:44:09  2023-01-21 20:48:08
#
#                          start_station_name start_station_id  \
# 0  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 1  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 2  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 3  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 4                             Hamilton Park            JC009
#
#                              end_station_name end_station_id  start_lat  \
# 0                               Hamilton Park          JC009  40.735938
# 1  Southwest Park - Jackson St & Observer Hwy          HB401  40.735938
# 2                          Marshall St & 2 St          HB408  40.735944
# 3                               Hamilton Park          JC009  40.735986
# 4                                Manila & 1st          JC082  40.727596
#
#    start_lng    end_lat    end_lng member_casual
# 0 -74.030305  40.727596 -74.044247        member
# 1 -74.030305  40.737551 -74.041664        member
# 2 -74.030383  40.740802 -74.042521        member
# 3 -74.030364  40.727596 -74.044247        member
# 4 -74.044247  40.721651 -74.042884        member

# %%
# import numpy as np
# main_df["lat1"] = np.radians(main_df["start_lat"])
# main_df["lat2"] = np.radians(main_df["end_lat"])
# main_df["lon1"] = np.radians(main_df["start_lng"])
# main_df["lon2"] = np.radians(main_df["end_lng"])
# main_df["dlon"] = main_df["lon2"] - main_df["lon1"]
# main_df["dlat"] = main_df["lat2"] - main_df["lat1"]

# %%
# a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
# c = 2 * atan2(sqrt(a), sqrt(1 - a))
# distance = R * c

# main_df["a"] = np.sin(main_df["dlat"] / 2)**2 + np.cos(main_df["lat1"]) * np.cos(main_df["lat2"]) * np.sin(main_df["dlon"] / 2)**2
# main_df["c"] = 2 * atan2(sqrt(main_df["a"]), sqrt(1 - main_df["a"]))

# %%
# main_df["c"] = 2 * np.arctan2(np.sqrt(main_df["a"]), np.sqrt(1 - main_df["a"]))

# %%
# main_df["distance"] = R*main_df["c"]

# %%
# Approximate radius of earth in km
R = 6373.0

import numpy as np

lat1 = np.radians(main_df["start_lat"])
lat2 = np.radians(main_df["end_lat"])
lng1 = np.radians(main_df["start_lng"])
lng2 = np.radians(main_df["end_lng"])
dlng = lng2 - lng1
dlat = lat2 - lat1

a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlng / 2)**2
c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))

main_df["distance"] = R*c

# %%
main_df.reset_index(inplace=True)

# %%
(pd.to_datetime(main_df.ended_at[0]) - pd.to_datetime(main_df.started_at[0])).total_seconds()/60
# Out:
# 10.7

# %%
main_df["duration_minutes"] = (pd.to_datetime(main_df["ended_at"]) - pd.to_datetime(main_df["started_at"])).dt.total_seconds()/60

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346019 entries, 0 to 346018
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               346019 non-null  int64
#  1   ride_id             346019 non-null  object
#  2   rideable_type       346019 non-null  object
#  3   started_at          346019 non-null  object
#  4   ended_at            346019 non-null  object
#  5   start_station_name  346019 non-null  object
#  6   start_station_id    346019 non-null  object
#  7   end_station_name    346019 non-null  object
#  8   end_station_id      346019 non-null  object
#  9   start_lat           346019 non-null  float64
#  10  start_lng           346019 non-null  float64
#  11  end_lat             346019 non-null  float64
#  12  end_lng             346019 non-null  float64
#  13  member_casual       346019 non-null  object
#  14  distance            346019 non-null  float64
#  15  duration_minutes    346019 non-null  float64
# dtypes: float64(6), int64(1), object(9)
# memory usage: 42.2+ MB

# %%
main_df.head()
# Out:
#    index           ride_id  rideable_type           started_at  \
# 0      0  0905B18B365C9D20   classic_bike  2023-01-28 09:18:10
# 1      1  B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12
# 2      2  5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04
# 3      3  E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08
# 4      4  323165780CA0734B   classic_bike  2023-01-21 20:44:09
#
#               ended_at                        start_station_name  \
# 0  2023-01-28 09:28:52  Hoboken Terminal - Hudson St & Hudson Pl
# 1  2023-01-23 20:18:27  Hoboken Terminal - Hudson St & Hudson Pl
# 2  2023-01-29 15:32:38  Hoboken Terminal - Hudson St & Hudson Pl
# 3  2023-01-24 18:42:13  Hoboken Terminal - Hudson St & Hudson Pl
# 4  2023-01-21 20:48:08                             Hamilton Park
#
#   start_station_id                            end_station_name end_station_id  \
# 0            HB101                               Hamilton Park          JC009
# 1            HB101  Southwest Park - Jackson St & Observer Hwy          HB401
# 2            HB101                          Marshall St & 2 St          HB408
# 3            HB101                               Hamilton Park          JC009
# 4            JC009                                Manila & 1st          JC082
#
#    start_lat  start_lng    end_lat    end_lng member_casual  distance  \
# 0  40.735938 -74.030305  40.727596 -74.044247        member  1.497317
# 1  40.735938 -74.030305  40.737551 -74.041664        member  0.974037
# 2  40.735944 -74.030383  40.740802 -74.042521        member  1.156913
# 3  40.735986 -74.030364  40.727596 -74.044247        member  1.496743
# 4  40.727596 -74.044247  40.721651 -74.042884        member  0.671198
#
#    duration_minutes
# 0         10.700000
# 1          8.250000
# 2          5.566667
# 3          7.083333
# 4          3.983333

# %%
import matplotlib.pyplot as plt
plt.hist(main_df["distance"],bins=100)
plt.show()

# %%
main_df.to_csv("main_distance.csv",index=False)

# %%
df1 = pd.read_csv("main_distance.csv",encoding="utf8")

# %%
df1.head()
# Out:
#    index           ride_id  rideable_type           started_at  \
# 0      0  0905B18B365C9D20   classic_bike  2023-01-28 09:18:10
# 1      1  B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12
# 2      2  5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04
# 3      3  E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08
# 4      4  323165780CA0734B   classic_bike  2023-01-21 20:44:09
#
#               ended_at                        start_station_name  \
# 0  2023-01-28 09:28:52  Hoboken Terminal - Hudson St & Hudson Pl
# 1  2023-01-23 20:18:27  Hoboken Terminal - Hudson St & Hudson Pl
# 2  2023-01-29 15:32:38  Hoboken Terminal - Hudson St & Hudson Pl
# 3  2023-01-24 18:42:13  Hoboken Terminal - Hudson St & Hudson Pl
# 4  2023-01-21 20:48:08                             Hamilton Park
#
#   start_station_id                            end_station_name end_station_id  \
# 0            HB101                               Hamilton Park          JC009
# 1            HB101  Southwest Park - Jackson St & Observer Hwy          HB401
# 2            HB101                          Marshall St & 2 St          HB408
# 3            HB101                               Hamilton Park          JC009
# 4            JC009                                Manila & 1st          JC082
#
#    start_lat  start_lng    end_lat    end_lng member_casual  distance  \
# 0  40.735938 -74.030305  40.727596 -74.044247        member  1.497317
# 1  40.735938 -74.030305  40.737551 -74.041664        member  0.974037
# 2  40.735944 -74.030383  40.740802 -74.042521        member  1.156913
# 3  40.735986 -74.030364  40.727596 -74.044247        member  1.496743
# 4  40.727596 -74.044247  40.721651 -74.042884        member  0.671198
#
#    duration_minutes
# 0         10.700000
# 1          8.250000
# 2          5.566667
# 3          7.083333
# 4          3.983333

# %%
df1.sort_values(by="distance",ascending=False,inplace=True)
df1.head()
# Out:
#         index           ride_id  rideable_type           started_at  \
# 243395  73787  6FAE805192732BBF   classic_bike  2023-04-13 15:21:06
# 274906  24771  ADB71C0AC1FBBBE5   classic_bike  2023-05-27 12:41:27
# 337412  87395  E6AE0F17BEB849B4  electric_bike  2023-05-07 15:00:48
# 24450   24618  E75A6F99FD1C62B0   classic_bike  2023-01-15 15:51:45
# 200478  30721  E9486AC98EDB46ED   classic_bike  2023-04-22 12:35:15
#
#                    ended_at                        start_station_name  \
# 243395  2023-04-13 17:34:42                        Liberty Light Rail
# 274906  2023-05-27 15:45:49                        Grant Ave & MLK Dr
# 337412  2023-05-07 16:49:20                          Marin Light Rail
# 24450   2023-01-15 17:01:02                             Grove St PATH
# 200478  2023-04-22 14:22:00  Hoboken Terminal - Hudson St & Hudson Pl
#
#        start_station_id                 end_station_name end_station_id  \
# 243395            JC052     W 180 St & Ft Washington Ave        8358.03
# 274906            JC107              Broadway & W 142 St        7981.16
# 337412            JC013  W 168th S & Fort Washington Ave        8226.07
# 24450             JC115       St Nicholas Ave & W 150 St        8013.07
# 200478            HB101         Wadsworth Ave & W 175 St        8299.03
#
#         start_lat  start_lng    end_lat    end_lng member_casual   distance  \
# 243395  40.711242 -74.055701  40.849972 -73.938423        casual  18.321633
# 274906  40.709085 -74.080617  40.824686 -73.951947        casual  16.817547
# 337412  40.714584 -74.042817  40.842102 -73.942240        member  16.521089
# 24450   40.719371 -74.043179  40.827212 -73.942722        member  14.679472
# 200478  40.735913 -74.030391  40.846052 -73.937648        casual  14.528481
#
#         duration_minutes
# 243395        133.600000
# 274906        184.366667
# 337412        108.533333
# 24450          69.283333
# 200478        106.750000

# %%
# from math import sin, cos, sqrt, atan2, radians

# # Approximate radius of earth in km
# R = 6373.0

# lat1 = radians(40.735938)
# lon1 = radians(-74.030305)
# lat2 = radians(40.727596)
# lon2 = radians(-74.044247)

# dlon = lon2 - lon1
# dlat = lat2 - lat1

# a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
# c = 2 * atan2(sqrt(a), sqrt(1 - a))

# distance = R * c

# print("Result: ", distance)
